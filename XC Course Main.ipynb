# %%
import pandas as pd
import XCCourseHelper as XC

# %%
DesiredCourseSummary = pd.read_csv(
            "./Course DataFrames/AllCoursesSummary.csv", index_col=0
        )
DesiredCourseSummary.index = DesiredCourseSummary['Course']
DesiredCourseSummary.drop(['Course'], axis=1, inplace=True)

# %%
DesiredCourseSummary
# Out:
#                             Turn Stdev  Total Degrees Turned  \
# Course
# King City 10km               18.538449          10872.224942
# Western International 10km   25.087925          10432.960096
# Louisville Classic 8km       19.738023           6781.403288
# Fort Henry 10km              25.759715          11634.607874
# Point Pleasant Park          34.124293          15666.400836
# Malden Park 10km             22.863487          12617.610143
# Moncton Classic 8km          28.408747          12423.227402
# Guelph Arboretum 7_5km       25.001218           8124.119437
# Fanshawe Invitational 8km    24.180206           8634.827413
# StFX Invitational 8km        58.441980          86506.596787
# Odell Park 7_5km             29.603465          11187.967765
# Guelph Arboretum 10km        24.354640          11532.607017
# Loyola Lakefront 8km         23.426609          10541.426992
# Victoria Park 6km            27.447763          10800.627071
# Abbotsford 10km              24.239590          14742.197129
# Terre Haute 10km             17.121751           4031.854408
# Western International 8km    28.512732           7912.138151
# Bayfront Park 7km            38.154110          56106.853306
#
#                             Perimeters/Total Distance  Course Area (m^2)  \
# Course
# King City 10km                           10038.907997     -950170.390341
# Western International 10km                9968.833143      460036.173499
# Louisville Classic 8km                    8540.026287      643863.731242
# Fort Henry 10km                          10110.727004     -324374.359032
# Point Pleasant Park                       9724.775310      228902.224241
# Malden Park 10km                          9634.529662     -651923.814169
# Moncton Classic 8km                       8300.695758      112459.945592
# Guelph Arboretum 7_5km                    7500.441631     -523345.157986
# Fanshawe Invitational 8km                 8126.288553      609178.006826
# StFX Invitational 8km                     7862.697327      209436.040107
# Odell Park 7_5km                          7984.955851     -282688.257068
# Guelph Arboretum 10km                    10088.535560     -665319.677772
# Loyola Lakefront 8km                      8107.435288      383615.593944
# Victoria Park 6km                         6025.609582      227856.418118
# Abbotsford 10km                          10007.719497      344111.183926
# Terre Haute 10km                         10307.794825     -476844.612398
# Western International 8km                 8000.926866      360970.044217
# Bayfront Park 7km                         8304.208521     -143937.636110
#
#                             Number of Hairpin Turns  Hill Stdev  \
# Course
# King City 10km                                    4    6.439814
# Western International 10km                        4    8.958747
# Louisville Classic 8km                            0    2.987805
# Fort Henry 10km                                   4    1.630665
# Point Pleasant Park                              16    8.122114
# Malden Park 10km                                  5    3.684066
# Moncton Classic 8km                               4    1.616720
# Guelph Arboretum 7_5km                            0    4.846169
# Fanshawe Invitational 8km                         4    2.476633
# StFX Invitational 8km                            71    4.948747
# Odell Park 7_5km                                  3    9.994810
# Guelph Arboretum 10km                             9    3.005646
# Loyola Lakefront 8km                              2    1.289145
# Victoria Park 6km                                 3    1.519160
# Abbotsford 10km                                   1    3.001226
# Terre Haute 10km                                  0    4.517600
# Western International 8km                         6    8.118299
# Bayfront Park 7km                                19    1.454025
#
#                             Tallest Hill (m)  Length of tallest hill (m)  \
# Course
# King City 10km                     31.700000                    0.894961
# Western International 10km         28.300000                    0.624000
# Louisville Classic 8km             13.400000                    2.369120
# Fort Henry 10km                     9.200000                    1.287430
# Point Pleasant Park                17.200000                    0.445803
# Malden Park 10km                    6.100000                    0.341589
# Moncton Classic 8km                 6.900000                    1.123406
# Guelph Arboretum 7_5km             12.700000                    0.320015
# Fanshawe Invitational 8km          10.600000                    2.082113
# StFX Invitational 8km              12.700000                    0.441403
# Odell Park 7_5km                   36.700000                    0.664571
# Guelph Arboretum 10km              14.500000                    0.514402
# Loyola Lakefront 8km                8.600000                    2.403455
# Victoria Park 6km                   5.600000                    0.670688
# Abbotsford 10km                    12.300000                    1.355669
# Terre Haute 10km                   14.580000                    0.772321
# Western International 8km          22.570833                    0.649597
# Bayfront Park 7km                   6.300000                    1.266446
#
#                             Number of Hills  Total Elevation Gain (m)  \
# Course
# King City 10km                            8                   2896.80
# Western International 10km                9                   3191.20
# Louisville Classic 8km                    2                   1072.80
# Fort Henry 10km                           3                   1329.55
# Point Pleasant Park                       8                   2615.45
# Malden Park 10km                          1                   1770.70
# Moncton Classic 8km                       3                    748.65
# Guelph Arboretum 7_5km                    8                   1754.15
# Fanshawe Invitational 8km                 6                   1416.45
# StFX Invitational 8km                     8                    839.60
# Odell Park 7_5km                          4                   3767.80
# Guelph Arboretum 10km                     4                   2565.35
# Loyola Lakefront 8km                      2                    982.15
# Victoria Park 6km                         3                    727.10
# Abbotsford 10km                           5                   2225.70
# Terre Haute 10km                          6                   4734.00
# Western International 8km                 6                   2333.40
# Bayfront Park 7km                         9                    721.50
#
#                             Total Elevation Gain Unfiltered (m)  Start Lat  \
# Course
# King City 10km                                      2897.610163  43.958538
# Western International 10km                          3191.301824  42.962418
# Louisville Classic 8km                              1074.025532  38.281832
# Fort Henry 10km                                     1329.333220  44.236265
# Point Pleasant Park                                 2616.215501  44.618740
# Malden Park 10km                                    1770.651961  42.279559
# Moncton Classic 8km                                  749.007982  46.106609
# Guelph Arboretum 7_5km                              1754.108838  43.541459
# Fanshawe Invitational 8km                           1416.372596  43.058170
# StFX Invitational 8km                                838.778387  45.616600
# Odell Park 7_5km                                    3767.319234  45.955450
# Guelph Arboretum 10km                               2566.951772  43.540751
# Loyola Lakefront 8km                                 982.060183  41.964434
# Victoria Park 6km                                    727.034675  46.229214
# Abbotsford 10km                                     2226.704691  49.069007
# Terre Haute 10km                                    4737.534861  39.460299
# Western International 8km                           2333.533375  42.962476
# Bayfront Park 7km                                    721.759387  43.271580
#
#                              Start Lon  Course Ave. GAP - Strava  \
# Course
# King City 10km              -79.513373               1073.531823
# Western International 10km  -81.301822                -53.716156
# Louisville Classic 8km      -85.556895                  1.054198
# Fort Henry 10km             -76.460620                  1.016291
# Point Pleasant Park         -63.565790                 42.698570
# Malden Park 10km            -83.068669                 -5.212872
# Moncton Classic 8km         -64.784758             -14505.365489
# Guelph Arboretum 7_5km      -80.223312             109416.270376
# Fanshawe Invitational 8km   -81.183843                 29.022356
# StFX Invitational 8km       -61.990704              16273.805299
# Odell Park 7_5km            -66.661154                 27.358406
# Guelph Arboretum 10km       -80.222459                 -0.271438
# Loyola Lakefront 8km        -87.637187                  1.301042
# Victoria Park 6km           -63.137150                  1.061642
# Abbotsford 10km            -122.335260             -30564.320791
# Terre Haute 10km            -87.260801                  1.026198
# Western International 8km   -81.302148                  1.831842
# Bayfront Park 7km           -79.872869                -17.863393
#
#                             Course Ave. GAP - Minetti
# Course
# King City 10km                            -976.706190
# Western International 10km                  87.114164
# Louisville Classic 8km                       1.021090
# Fort Henry 10km                              1.015434
# Point Pleasant Park                        -30.216389
# Malden Park 10km                            13.498179
# Moncton Classic 8km                      17278.672952
# Guelph Arboretum 7_5km                 -109539.812974
# Fanshawe Invitational 8km                  -20.494138
# StFX Invitational 8km                   -15843.841782
# Odell Park 7_5km                            -8.518240
# Guelph Arboretum 10km                        4.930564
# Loyola Lakefront 8km                         1.902704
# Victoria Park 6km                            1.128513
# Abbotsford 10km                          35928.840141
# Terre Haute 10km                             1.046952
# Western International 8km                    1.068569
# Bayfront Park 7km                           33.425357

# %%
XC.XCMain()
# Out:
# .DS_Store
# .ipynb_checkpoints
# Abbotsford 10km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Bayfront Park 7km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Beacon Hill Park 10km
# Fanshawe Invitational 8km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Fort Henry 10km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Guelph Arboretum 10km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# one hill error
# Guelph Arboretum 7_5km.gpx
# C:\Users\jwals\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# King City 10km.gpx
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15144/2910546041.py in <module>
# ----> 1 XC.XCMain()
#
# c:\Users\jwals\OneDrive\Documents\GitHub\XCCourseAnalysis\XCCourseHelper.py in XCMain()
#     627             if os.path.isfile(FilePath):
#     628                 CourseName = filename[0:-4]
# --> 629                 CourseInformation, df = GetCourseInformation(CourseName, FilePath)
#     630                 CourseInformationList.append(CourseInformation)
#     631                 dfs.append(df)
#
# c:\Users\jwals\OneDrive\Documents\GitHub\XCCourseAnalysis\XCCourseHelper.py in GetCourseInformation(course, gpx_file)
#     553
#     554 def GetCourseInformation(course, gpx_file):
# --> 555     df, turn_st_dev, tot_deg_turned, HairpinCount, perim, area = MakeInitialDataframe(
#     556         course, gpx_file
#     557     )
#
# c:\Users\jwals\OneDrive\Documents\GitHub\XCCourseAnalysis\XCCourseHelper.py in MakeInitialDataframe(CourseName, gpx_file)
#     176
#     177 def MakeInitialDataframe(CourseName, gpx_file):
# --> 178     df = LoadRunIntoDF(gpx_file)
#     179
#     180     df["DistanceChangeInKM"] = df["Distance"] - df["Distance"].shift()
#
# c:\Users\jwals\OneDrive\Documents\GitHub\XCCourseAnalysis\XCCourseHelper.py in LoadRunIntoDF(filename)
#     289
#     290 def LoadRunIntoDF(filename):
# --> 291     run_data = ParseGPX(filename)
#     292     df = ParsedGPXToDF(run_data)
#     293     df["time"] = pd.to_datetime(df["time"])
#
# c:\Users\jwals\OneDrive\Documents\GitHub\XCCourseAnalysis\XCCourseHelper.py in ParseGPX(filename)
#     240 def ParseGPX(filename):
#     241     with open(filename) as f:
# --> 242         run_data = gpxpy.parse(f)
#     243     f.closed
#     244     return run_data
#
# ~\anaconda3\lib\site-packages\gpxpy\__init__.py in parse(xml_or_file, version)
#      35     from . import parser as mod_parser
#      36
# ---> 37     parser = mod_parser.GPXParser(xml_or_file)
#      38
#      39     return parser.parse(version)
#
# ~\anaconda3\lib\site-packages\gpxpy\parser.py in __init__(self, xml_or_file)
#      68         """
#      69         self.xml = ""
# ---> 70         self.init(xml_or_file)
#      71         self.gpx = mod_gpx.GPX()
#      72
#
# ~\anaconda3\lib\site-packages\gpxpy\parser.py in init(self, xml_or_file)
#      80
#      81         """
# ---> 82         text = xml_or_file.read() if hasattr(xml_or_file, 'read') else xml_or_file # type: ignore
#      83         if isinstance(text, bytes):
#      84             text = text.decode()
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 633: character maps to <undefined>
